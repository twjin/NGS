# %% [markdown]
# How to get distribution of insert size ?
# ====

# %%
from IPython.display import Image
insertsize = Image( "./Insert_Size.png")
insertsize

# %% [raw]
# $samtools view -f66 PEreads_alignment.bam | cut -f 9 | sed 's/^-//' > insert-size-list.txt
# $samtools view -f66 -q 20 PEreads_alignment.bam | cut -f 9 | sed 's/^/-//' > insert-size-list.txt

# %% [markdown]
# reference:
#
# [UC Davis Bioinformatics] http://training.bioinformatics.ucdavis.edu/docs/2013/09/rna-seq-workshop-2013/RNA-Seq-tophat-cufflinks.html
#
# [GeneScripts] http://www.genescripts.com/calculating-insert-size.php
#
# [Tiki] http://davetang.org/wiki/tiki-index.php?page=SAM
